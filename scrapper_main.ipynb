# %%
#Stock data scraper for stonk analysis
#Sava to file or just display data and make models from data.

#UsingYahoo finance and if not then using a site with scraping enabled

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pylab as plt
import pandas as pd
import json
import time
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#from scrapper_class import Scrape
#stock = Scrape()

#tickerName = "MRP.JO"

#data = stock.runner(tickerName)


#Here we have json file to manipulate the data
# Out:
# Fetching data for MRP.JO
# Parsing https://finance.yahoo.com/quote/MRP.JO?p=MRP.JO
# Writing data to output file

# %%
#for name in data:
#    if(isinstance(data[name], float)):
#        print(name + " = " + str(data[name]))
#    else: 
#        print(name + " = " + data[name])
#
# Out:
# Previous Close = 14,485.00
# Open = 14,400.00
# Bid = 14,298.00 x 0
# Ask = 14,299.00 x 0
# Day's Range = 14,268.00 - 14,682.00
# 52 Week Range = 9,820.00 - 20,605.00
# Volume = 1,056,840
# Avg. Volume = 1,589,594
# Market Cap = 37.079B
# Beta (5Y Monthly) = 0.99
# PE Ratio (TTM) = 1,395.49
# EPS (TTM) = 10.248
# Earnings Date = 2020-06-25
# Forward Dividend & Yield = 7.36 (5.15%)
# Ex-Dividend Date = Dec 11, 2019
# 1y Target Est = 242.21
# ticker = MRP.JO
# url = https://finance.yahoo.com/quote/MRP.JO?p=MRP.JO

# %%
from big_stock_tickers import Tickers
from scrapper_class import Scrape
stock = Scrape()
stock_tickers = Tickers.get_tickers()
for tickers in stock_tickers:
    print("\n")
    data = stock.runner(tickers)
    for name in data:
        if(isinstance(data[name], float)):
            print(name + " = " + str(data[name]))
        else: 
            print(name + " = " + data[name])
    print("\n")
    time.sleep(2)
# Out:
# Fetching data for 4SI.JO
# Parsing https://finance.yahoo.com/quote/4SI.JO?p=4SI.JO
# Data retrieved successfully
# error = Unhandled Error
#
#
#
#
# Fetching data for ABSP.JO
# Parsing https://finance.yahoo.com/quote/ABSP.JO?p=ABSP.JO
# Data retrieved successfully
# error = Unhandled Error
#
#
#
#
# Fetching data for ABG.JO
# Parsing https://finance.yahoo.com/quote/ABG.JO?p=ABG.JO
# Data retrieved successfully
# Previous Close = 8,862.00
# Open = 8,804.00
# Bid = 8,528.00 x 0
# Ask = 8,540.00 x 0
# Day's Range = 8,522.00 - 8,931.00
# 52 Week Range = 6,330.00 - 17,646.00
# Volume = 5,626,633
# Avg. Volume = 4,491,450
# Market Cap = 70.682B
# Beta (5Y Monthly) = 0.96
# PE Ratio (TTM) = 497.35
# EPS (TTM) = 17.151
# Earnings Date = 2020-08-12
# Forward Dividend & Yield = 12.40 (14.38%)
# Ex-Dividend Date = Apr 15, 2020
# 1y Target Est = 190.37
# ticker = ABG.JO
# url = https://finance.yahoo.com/quote/ABG.JO?p=ABG.JO
#
#
#
#
# Fetching data for APF.JO
# ...
